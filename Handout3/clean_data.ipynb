# %%
import pandas as pd
import os

base_path = os.getcwd()
file_path = os.path.join(base_path, 'dataset', 'vietnam_ecommerce_2023.csv')

df = pd.read_csv(file_path)

# 1. Kiểm tra kích thước 
print(f"Số lượng dòng: {df.shape[0]}")
print(f"Số lượng cột: {df.shape[1]}")

# 2. Xem 5 dòng đầu tiên 
display(df.head())

# 3. Kiểm tra kiểu dữ liệu và giá trị non-null
df.info()
# Out:
# Số lượng dòng: 8000
# Số lượng cột: 27
#        order_id  order_date  month quarter day_of_week customer_id gender  \
# 0  DH2023006817  2023-01-01      1      Q1      Sunday     KH00664    Nam
# 1  DH2023002181  2023-01-01      1      Q1      Sunday     KH04895    Nam
# 2  DH2023007291  2023-01-01      1      Q1      Sunday     KH03040    Nam
# 3  DH2023002072  2023-01-01      1      Q1      Sunday     KH01387    Nam
# 4  DH2023003808  2023-01-01      1      Q1      Sunday     KH04611    Nam
#
#   age_group      city    region  ... discount_amount net_value shipping_fee  \
# 0       55+    Hà Nội  Miền Bắc  ...               0     51028        25000
# 1     25-34    Hà Nội  Miền Bắc  ...           94948    538040            0
# 2     35-44    Hà Nội  Miền Bắc  ...           38244    344205        20000
# 3     18-24  Vũng Tàu  Miền Nam  ...               0    469671        25000
# 4     45-54   Cần Thơ  Miền Nam  ...               0    409456        20000
#
#    free_shipping  total_paid  delivery_days  returned  rating  campaign  \
# 0          False       76028              2     False       5       NaN
# 1           True      538040              1     False       5       NaN
# 2          False      364205              3     False       3       NaN
# 3          False      494671              2     False       5       NaN
# 4          False      429456              3     False       4       NaN
#
#    profit
# 0   -9692
# 1  215216
# 2  110797
# 3  153474
# 4  151971
#
# [5 rows x 27 columns]
# <class 'pandas.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 27 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   order_id         8000 non-null   str
#  1   order_date       8000 non-null   str
#  2   month            8000 non-null   int64
#  3   quarter          8000 non-null   str
#  4   day_of_week      8000 non-null   str
#  5   customer_id      8000 non-null   str
#  6   gender           8000 non-null   str
#  7   age_group        8000 non-null   str
#  8   city             8000 non-null   str
#  9   region           8000 non-null   str
#  10  channel          8000 non-null   str
#  11  payment_method   8000 non-null   str
#  12  category         8000 non-null   str
#  13  quantity         8000 non-null   int64
#  14  unit_price       8000 non-null   int64
#  15  gross_value      8000 non-null   int64
#  16  discount_pct     8000 non-null   float64
#  17  discount_amount  8000 non-null   int64
#  18  net_value        8000 non-null   int64
#  19  shipping_fee     8000 non-null   int64
#  20  free_shipping    8000 non-null   bool
#  21  total_paid       8000 non-null   int64
#  22  delivery_days    8000 non-null   int64
#  23  returned         8000 non-null   bool
#  24  rating           8000 non-null   int64
#  25  campaign         468 non-null    str
#  26  profit           8000 non-null   int64
# dtypes: bool(2), float64(1), int64(11), str(13)
# memory usage: 2.3 MB
